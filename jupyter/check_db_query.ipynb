# %%
# %pwd
# Out:
# '/home/taindp/PycharmProjects/thesis/jupyter'

# %%
import sys
import pymongo
# sys.path

# %%
sys.path.append('/home/taindp/PycharmProjects/thesis/')

# %%
from response.user_request import *
from entity.pattern_ner import *
from response.agent_action import *
from response.constants_response import *
# Out:
# Using TensorFlow backend.

# %%
# %load_ext autoreload
# %autoreload 2
from dqn.dqn_agent import DQNAgent
from dqn.state_tracker import StateTracker
from dqn.db_query import DBQuery

# %%
# FOLDER_PATH = '/home/taindp/PycharmProjects/thesis/dqn'
# CONSTANTS_FILE_PATH = f'{FOLDER_PATH}/constants.json'
# constants_file = CONSTANTS_FILE_PATH
# with open(constants_file) as f:
#     constants = json.load(f)
# file_path_dict = constants['db_file_paths']
# DATABASE_FILE_PATH = file_path_dict['database']

# %%
# file_path_dict

# %%
client = pymongo.MongoClient("mongodb://taindp:chatbot2020@thesis-shard-00-00.bdisf.mongodb.net:27017,thesis-shard-00-01.bdisf.mongodb.net:27017,thesis-shard-00-02.bdisf.mongodb.net:27017/<dbname>?ssl=true&replicaSet=atlas-12fynb-shard-0&authSource=admin&retryWrites=true&w=majority")
# client = pymongo.MongoClient('')
database = client.hcmut
# collection = db['general'].find({})
# collection = db['general']
# database = []
# for item in collection:
#     database.append(item)
# database= json.load(open(DATABASE_FILE_PATH,encoding='utf-8'))

# %%
# database

# %%
# state_tracker = StateTracker(database, constants)

# %%
# dqn_agent = DQNAgent(state_tracker.get_state_size(), constants)

# %%
# # mess1 = 'cho mình hỏi học phí của trường có đắt không ạ'
# mess1 = 'cho em xin điểm chuẩn ngành điện tử  khối a năm 2019 với ạ'
# user_action, confirm_obj = user_request(mess1,state_tracker)
# user_action

# %%
# client = pymongo.MongoClient("mongodb://taindp:chatbot2020@thesis-shard-00-00.bdisf.mongodb.net:27017,thesis-shard-00-01.bdisf.mongodb.net:27017,thesis-shard-00-02.bdisf.mongodb.net:27017/<dbname>?ssl=true&replicaSet=atlas-12fynb-shard-0&authSource=admin&retryWrites=true&w=majority")
# # client = pymongo.MongoClient('')
# db = client.hcmut
# collection = db['general'].find({})
# # collection = db['general']
# database = []
# for item in collection:
#     database.append(item)

# %%
dbquery = DBQuery(database)
# constraint = {'major_name': ['điện tử'],'point':[float(20),float(27)]}
# constraint = {'major_name': ['bảo dưỡng công nghiệp'], 'type_edu': ['chính quy'], 'case': 'anything', 'subject_group': []}
constraint = {'case': ['thi']}

# constraint = {}
user_action = {}
user_action['intent'] = 'request'
dbquery.get_db_results(constraint,user_action)
# Out:
# {'case': ['thi']}
# ['thi tốt nghiệp trung học phổ thông', 'ưu tiên xét tuyển', 'đánh giá năng lực']
# {'60588c802c992394968d363c': {'_id': '60588c802c992394968d363c',
#   'major_code': ['108'],
#   'major_name': ['kỹ thuật điện'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [26.75],
#   'year': ['2020'],
#   'career': ['thiết kế thiết bị điện và điện tử công suất',
#    'thiết kế bộ điều khiển máy điện',
#    'thiết kế hệ thống năng lượng tái tạo',
#    'thiết kế mạng điện',
#    'thiết kế trạm biến áp',
#    'thiết kế nhà máy điện',
#    'thiết kế và lập trình giải thuật điều khiển thiết bị và hệ thống điện',
#    'quản lý và vận hành lưới điện',
#    'thiết kế chiếu sáng',
#    'phân tích ổn định thiết bị và nguồn điện',
#    'bảo vệ relay và tự động hóa hệ thống điện',
#    'kỹ thuật cao áp',
#    'vật liệu cách điện',
#    'phân tích dữ liệu khoa học',
#    'phân tích hệ thống',
#    'điều khiển quá trình thời gian thực và lập trình giao tiếp người sử dụng'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [670],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d363d': {'_id': '60588c802c992394968d363d',
#   'major_code': ['125'],
#   'major_name': ['kỹ thuật môi trường'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [24.25],
#   'year': ['2020'],
#   'career': ['tư vấn thiết kế và thi công xây dựng công trình',
#    'cơ sở hạ tầng kỹ thuật liên quan đến vệ sinh môi trường'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d363e': {'_id': '60588c802c992394968d363e',
#   'major_code': ['441'],
#   'major_name': ['bảo dưỡng công nghiệp'],
#   'type_edu': ['phân hiệu bến tre'],
#   'point': [20.5],
#   'year': ['2020'],
#   'career': ['tổ chức quản lý bảo dưỡng',
#    'tổ chức quản lý kho',
#    'sửa chữa máy móc',
#    'duy trì sản xuất liên tục và cung cấp dịch vụ bảo trì hậu mãi'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [0],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d363f': {'_id': '60588c802c992394968d363f',
#   'major_code': ['245'],
#   'major_name': ['kỹ thuật hàng không'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [24.25],
#   'year': ['2020'],
#   'career': ['quản lý điều hành hoạt động bảo dưỡng máy bay',
#    'nghiên cứu thiết kế các thiết bị bay',
#    'tư vấn thiết kế cơ khí các hệ thống năng lượng và quy trình sản xuất'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [40],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3640': {'_id': '60588c802c992394968d3640',
#   'major_code': ['114'],
#   'major_name': ['kỹ thuật hóa học'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [26.75],
#   'year': ['2020'],
#   'career': ['quản lý vận hành và vận hành các hệ thống thiết bị công nghệ sản xuất ngành hóa',
#    'nghiên cứu và phát triển sản phẩm',
#    'phân tích và quản lý chất lượng sản phẩm'],
#   'subject': ['toán', 'hóa học', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['d07', 'd7'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [320],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3641': {'_id': '60588c802c992394968d3641',
#   'major_code': ['112'],
#   'major_name': ['công nghệ may'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [78.8],
#   'year': ['2020'],
#   'career': ['thiết kế trong các dây chuyền sản xuất',
#    'thiết kế kỹ thuật tại các phòng kỹ thuật',
#    'quản đốc xưởng sản xuất',
#    'quản lý các dự án về ngành may'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3642': {'_id': '60588c802c992394968d3642',
#   'major_code': ['223'],
#   'major_name': ['quản lý công nghiệp'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [23.75],
#   'year': ['2020'],
#   'career': ['quản lý nhà máy',
#    'hoạch định sản xuất',
#    'quản lý mua hàng và tồn kho',
#    'đánh giá trình độ công nghệ',
#    'quản lý con người',
#    'quản lý mua hàng',
#    'đánh giá các chương trình mua hàng',
#    'thiếp lập cấp độ vận hành và phối hợp các công tác trong vận hành',
#    'định hướng các điểm mấu chốt trong vận hành',
#    'quản lý chất lượng',
#    'phân tích chi tiết cơ sở dữ liệu và các bảng tính',
#    'kiểm định quá trình để xác định các khu vực cần cải tiến',
#    'quản lý việc thực hiện những thay đổi',
#    'lập kế hoạch và quản lý chuỗi cung ứng'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3643': {'_id': '60588c802c992394968d3643',
#   'major_code': ['114'],
#   'major_name': ['công nghệ thực phẩm'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [82.7],
#   'year': ['2020'],
#   'career': ['vận hành sản xuất thực phẩm',
#    'kiểm tra chất lượng sản phẩm thực phẩm',
#    'đảm bảo chất lượng sản phẩm thực phẩm',
#    'phân tích chất lượng và an toàn thực phẩm',
#    'thiết kế sản phẩm thực phẩm',
#    'quản lý an toàn thực phẩm',
#    'phụ trách dinh dưỡng thực phẩm'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [320],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3644': {'_id': '60588c802c992394968d3644',
#   'major_code': ['112'],
#   'major_name': ['kỹ thuật dệt'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [23.5],
#   'year': ['2020'],
#   'career': ['quản lý vận hành các dây chuyền sản xuất sợi dệt nhuộm',
#    'quản đốc xưởng sản xuất'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3645': {'_id': '60588c802c992394968d3645',
#   'major_code': ['109'],
#   'major_name': ['kỹ thuật cơ khí'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [72.5],
#   'year': ['2020'],
#   'career': ['chế tạo',
#    'điều hành',
#    'sản xuất',
#    'nghiên cứu phát triển',
#    'thiết kế sản phẩm cơ khí',
#    'tư vấn thiết kế',
#    'hệ thống nâng vận chuyển trong hệ thống dây chuyền tự động',
#    'sản xuất vật liệu xây dựng',
#    'sản xuất vật liệu và cấu kiện xây dựng',
#    'máy thi công cơ giới và máy chuyên dụng'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [300],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3646': {'_id': '60588c802c992394968d3646',
#   'major_code': ['114'],
#   'major_name': ['công nghệ sinh học'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [82.7],
#   'year': ['2020'],
#   'career': ['nghiên cứu trong phòng thí nghiệm ở các trường đại học các cơ quan pháp y các trung tâm và viện nghiên cứu',
#    'xây dựng quy trình sản xuất cũng như quản lý điều hành và kiểm soát quá trình sản xuất các sản phẩm công nghệ sinh học ở các qui mô khác nhau',
#    'xây dựng và thực hiện các dự án liên quan đến xử lý ô nhiễm môi trường sống'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [320],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3647': {'_id': '60588c802c992394968d3647',
#   'major_code': ['109'],
#   'major_name': ['kỹ thuật cơ khí'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [700.0],
#   'year': ['2020'],
#   'career': ['chế tạo',
#    'điều hành',
#    'sản xuất',
#    'nghiên cứu phát triển',
#    'thiết kế sản phẩm cơ khí',
#    'tư vấn thiết kế',
#    'hệ thống nâng vận chuyển trong hệ thống dây chuyền tự động',
#    'sản xuất vật liệu xây dựng',
#    'sản xuất vật liệu và cấu kiện xây dựng',
#    'máy thi công cơ giới và máy chuyên dụng'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [300],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3648': {'_id': '60588c802c992394968d3648',
#   'major_code': ['115'],
#   'major_name': ['kỹ thuật xây dựng công trình thủy'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [700.0],
#   'year': ['2020'],
#   'career': ['thiết kế thi công và quản lý các công trình chuyên ngành xây dựng các công trình thủy lợi thủy điện'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [645],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3649': {'_id': '60588c802c992394968d3649',
#   'major_code': ['228'],
#   'major_name': ['logistics và quản lý chuỗi cung ứng'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [81.8],
#   'year': ['2020'],
#   'career': ['quản lý và điều hành hệ thống sản xuất hay dịch vụ',
#    'quản lý vật tư và hoạch định tồn kho',
#    'các kỹ thuật tối ưu hóa nguồn lực sản xuất',
#    'kỹ thuật hỗ trợ ra quyết định',
#    'quản lý và kiểm soát chất lượng',
#    'logistics và chuỗi cung ứng',
#    'kỹ thuật điều độ nguồn lực',
#    'thiết kế hệ thống thông tin',
#    'thiết kế và áp dụng hệ thống sản xuất tinh gọn cho tổ chức'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [40],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d364a': {'_id': '60588c802c992394968d364a',
#   'major_code': ['123'],
#   'major_name': ['quản lý công nghiệp'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [820.0],
#   'year': ['2020'],
#   'career': ['quản lý nhà máy',
#    'hoạch định sản xuất',
#    'quản lý mua hàng và tồn kho',
#    'đánh giá trình độ công nghệ',
#    'quản lý con người',
#    'quản lý mua hàng',
#    'đánh giá các chương trình mua hàng',
#    'thiếp lập cấp độ vận hành và phối hợp các công tác trong vận hành',
#    'định hướng các điểm mấu chốt trong vận hành',
#    'quản lý chất lượng',
#    'phân tích chi tiết cơ sở dữ liệu và các bảng tính',
#    'kiểm định quá trình để xác định các khu vực cần cải tiến',
#    'quản lý việc thực hiện những thay đổi',
#    'lập kế hoạch và quản lý chuỗi cung ứng'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d364b': {'_id': '60588c802c992394968d364b',
#   'major_code': ['128'],
#   'major_name': ['kỹ thuật hệ thống công nghiệp'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [906.0],
#   'year': ['2020'],
#   'career': ['quản lý và điều hành hệ thống sản xuất hay dịch vụ',
#    'quản lý vật tư và hoạch định tồn kho',
#    'các kỹ thuật tối ưu hóa nguồn lực sản xuất',
#    'kỹ thuật hỗ trợ ra quyết định',
#    'quản lý và kiểm soát chất lượng',
#    'logistics và chuỗi cung ứng',
#    'kỹ thuật điều độ nguồn lực',
#    'thiết kế hệ thống thông tin',
#    'thiết kế và áp dụng hệ thống sản xuất tinh gọn cho tổ chức'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d364c': {'_id': '60588c802c992394968d364c',
#   'major_code': ['206'],
#   'major_name': ['khoa học máy tính'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [926.0],
#   'year': ['2020'],
#   'career': ['thiết kế xây dựng các phần mềm máy tính',
#    'thiết kế xây dựng các ứng dụng cho thiết bị di động',
#    'ứng dụng thương mại điện tử trên nền web',
#    'quản trị và xây dựng các giải pháp đảm bảo an toàn cho các hệ thống máy tính và hệ thống mạng máy tính',
#    'tư vấn thẩm định và phát triển các dự án giải pháp công nghệ thông tin'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [100],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d364d': {'_id': '60588c802c992394968d364d',
#   'major_code': ['125'],
#   'major_name': ['kỹ thuật môi trường'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [24.25],
#   'year': ['2020'],
#   'career': ['tư vấn thiết kế và thi công xây dựng công trình',
#    'cơ sở hạ tầng kỹ thuật liên quan đến vệ sinh môi trường'],
#   'subject': ['toán', 'hóa học', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['d07', 'd7'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d364e': {'_id': '60588c802c992394968d364e',
#   'major_code': ['237'],
#   'major_name': ['vật lý kỹ thuật'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [704.0],
#   'year': ['2020'],
#   'career': ['kỹ sư lâm sàng',
#    'chuyên gia thiết bị y tế',
#    'kinh doanh và sản xuất thiết bị y tế thiết bị trong lĩnh vực công nghệ sinh học công nghệ môi trường'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [45],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d364f': {'_id': '60588c802c992394968d364f',
#   'major_code': ['115'],
#   'major_name': ['công nghệ kỹ thuật vật liệu xây dựng'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [70.6],
#   'year': ['2020'],
#   'career': ['giám sát và kiểm tra chất lượng vật liệu xây dựng',
#    'kiểm định chất lượng của toàn bộ công trình xây dựng',
#    'sản xuất vật liệu xây dựng',
#    'giám sát chất lượng sản xuất sản phẩm'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [645],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3650': {'_id': '60588c802c992394968d3650',
#   'major_code': ['123'],
#   'major_name': ['quản lý công nghiệp'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [79.3],
#   'year': ['2020'],
#   'career': ['quản lý nhà máy',
#    'hoạch định sản xuất',
#    'quản lý mua hàng và tồn kho',
#    'đánh giá trình độ công nghệ',
#    'quản lý con người',
#    'quản lý mua hàng',
#    'đánh giá các chương trình mua hàng',
#    'thiếp lập cấp độ vận hành và phối hợp các công tác trong vận hành',
#    'định hướng các điểm mấu chốt trong vận hành',
#    'quản lý chất lượng',
#    'phân tích chi tiết cơ sở dữ liệu và các bảng tính',
#    'kiểm định quá trình để xác định các khu vực cần cải tiến',
#    'quản lý việc thực hiện những thay đổi',
#    'lập kế hoạch và quản lý chuỗi cung ứng'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3651': {'_id': '60588c802c992394968d3651',
#   'major_code': ['207'],
#   'major_name': ['kỹ thuật máy tính'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [26.25],
#   'year': ['2020'],
#   'career': ['thiết kế và xây dựng các phầm mềm phần cứng cho các thiết bị điều khiển tự động',
#    'quản trị và xây dựng các giải pháp đảm bảo an toàn cho các hệ thống máy tính và mạng máy tính',
#    'tư vấn thẩm định và phát triển các dự án giải pháp công nghệ thông tin'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [55],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3652': {'_id': '60588c802c992394968d3652',
#   'major_code': ['125'],
#   'major_name': ['quản lý tài nguyên môi trường'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [702.0],
#   'year': ['2020'],
#   'career': ['quản lý dự án các doanh nghiệp sản xuất các khu công nghiệp',
#    'tư vấn môi trường',
#    'quản lý tài nguyên môi trường',
#    'ban quản lý cải thiện vệ sinh môi trường các lưu vực thoát nước',
#    'cải tạo chất lượng nước trong lưu vực sông',
#    'quản lý chất thải rắn',
#    'lập báo cáo đánh giá tác động môi trường'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3653': {'_id': '60588c802c992394968d3653',
#   'major_code': ['115'],
#   'major_name': ['kỹ thuật xây dựng công trình cảng biển'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [24.0],
#   'year': ['2020'],
#   'career': ['thiết kế',
#    'thi công',
#    'giám sát',
#    'quản lý dự án',
#    'xây dựng cảng',
#    'công trình biển',
#    'công trình dầu khí',
#    'công trình giao thông',
#    'quản lý các sở ban ngành xây dựng giao thông thuỷ lợi nông nghiệp',
#    'ban quản lý các cảng',
#    'ban quản lý các dự án đường thuỷ',
#    'ban quản lý các chương trình tôn tạo bảo vệ bờ biển hải đảo',
#    'các chương trình ứng phó biến đổi khí hậu nước biển dâng'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [645],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3654': {'_id': '60588c802c992394968d3654',
#   'major_code': ['123'],
#   'major_name': ['quản lý công nghiệp'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [26.5],
#   'year': ['2020'],
#   'career': ['quản lý nhà máy',
#    'hoạch định sản xuất',
#    'quản lý mua hàng và tồn kho',
#    'đánh giá trình độ công nghệ',
#    'quản lý con người',
#    'quản lý mua hàng',
#    'đánh giá các chương trình mua hàng',
#    'thiếp lập cấp độ vận hành và phối hợp các công tác trong vận hành',
#    'định hướng các điểm mấu chốt trong vận hành',
#    'quản lý chất lượng',
#    'phân tích chi tiết cơ sở dữ liệu và các bảng tính',
#    'kiểm định quá trình để xác định các khu vực cần cải tiến',
#    'quản lý việc thực hiện những thay đổi',
#    'lập kế hoạch và quản lý chuỗi cung ứng'],
#   'subject': ['ngữ văn', 'toán', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['d01', 'd1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3655': {'_id': '60588c802c992394968d3655',
#   'major_code': ['219'],
#   'major_name': ['công nghệ thực phẩm'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [25.0],
#   'year': ['2020'],
#   'career': ['vận hành sản xuất thực phẩm',
#    'kiểm tra chất lượng sản phẩm thực phẩm',
#    'đảm bảo chất lượng sản phẩm thực phẩm',
#    'phân tích chất lượng và an toàn thực phẩm',
#    'thiết kế sản phẩm thực phẩm',
#    'quản lý an toàn thực phẩm',
#    'phụ trách dinh dưỡng thực phẩm'],
#   'subject': ['toán', 'hóa học', 'sinh học'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['b00', 'b'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [40],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3656': {'_id': '60588c802c992394968d3656',
#   'major_code': ['237'],
#   'major_name': ['vật lý kỹ thuật'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [23.0],
#   'year': ['2020'],
#   'career': ['kỹ sư lâm sàng',
#    'chuyên gia thiết bị y tế',
#    'kinh doanh và sản xuất thiết bị y tế thiết bị trong lĩnh vực công nghệ sinh học công nghệ môi trường'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [45],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3657': {'_id': '60588c802c992394968d3657',
#   'major_code': ['242'],
#   'major_name': ['công nghệ kỹ thuật ô tô'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [25.75],
#   'year': ['2020'],
#   'career': ['tư vấn và chuyển giao công nghệ lĩnh vực ô tô và giao thông vận tải đường bộ',
#    'công nghiệp sản xuất và lắp ráp ô tô'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [50],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3658': {'_id': '60588c802c992394968d3658',
#   'major_code': ['125'],
#   'major_name': ['quản lý tài nguyên môi trường'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [72.0],
#   'year': ['2020'],
#   'career': ['quản lý dự án các doanh nghiệp sản xuất các khu công nghiệp',
#    'tư vấn môi trường',
#    'quản lý tài nguyên môi trường',
#    'ban quản lý cải thiện vệ sinh môi trường các lưu vực thoát nước',
#    'cải tạo chất lượng nước trong lưu vực sông',
#    'quản lý chất thải rắn',
#    'lập báo cáo đánh giá tác động môi trường'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3659': {'_id': '60588c802c992394968d3659',
#   'major_code': ['141'],
#   'major_name': ['bảo dưỡng công nghiệp'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [21.25],
#   'year': ['2020'],
#   'career': ['tổ chức quản lý bảo dưỡng',
#    'tổ chức quản lý kho',
#    'sửa chữa máy móc',
#    'duy trì sản xuất liên tục và cung cấp dịch vụ bảo trì hậu mãi'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [165],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d365a': {'_id': '60588c802c992394968d365a',
#   'major_code': ['108'],
#   'major_name': ['kỹ thuật điện tử viễn thông'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [736.0],
#   'year': ['2020'],
#   'career': ['vận hành quản lý khai thác và thiết kế các mạng điện thoại cố định và di động mạng truyền dẫn quang viba thông tin vệ tinh phát thanh truyền hình mạng thông tin dữ liệu',
#    'phân tích và thiết kế các thiết bị thu phát cao tần các vi mạch số và vi mạch tương tự',
#    'vận hành máy móc trong nhà máy chế tạo linh kiện bán dẫn',
#    'lập trình và thiết kế phần cứng xử lý tín hiệu âm thanh hình ảnh và tín hiệu đa phương tiện'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [670],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d365b': {'_id': '60588c802c992394968d365b',
#   'major_code': ['106'],
#   'major_name': ['khoa học máy tính'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [927.0],
#   'year': ['2020'],
#   'career': ['thiết kế xây dựng các phần mềm máy tính',
#    'thiết kế xây dựng các ứng dụng cho thiết bị di động',
#    'ứng dụng thương mại điện tử trên nền web',
#    'quản trị và xây dựng các giải pháp đảm bảo an toàn cho các hệ thống máy tính và hệ thống mạng máy tính',
#    'tư vấn thẩm định và phát triển các dự án giải pháp công nghệ thông tin'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [240],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d365c': {'_id': '60588c802c992394968d365c',
#   'major_code': ['107'],
#   'major_name': ['kỹ thuật máy tính'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [898.0],
#   'year': ['2020'],
#   'career': ['thiết kế và xây dựng các phầm mềm phần cứng cho các thiết bị điều khiển tự động',
#    'quản trị và xây dựng các giải pháp đảm bảo an toàn cho các hệ thống máy tính và mạng máy tính',
#    'tư vấn thẩm định và phát triển các dự án giải pháp công nghệ thông tin'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [100],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d365d': {'_id': '60588c802c992394968d365d',
#   'major_code': ['129'],
#   'major_name': ['kỹ thuật vật liệu'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [75.1],
#   'year': ['2020'],
#   'career': ['sản xuất gia công vật liệu',
#    'chế tạo vật tư và thiết bị dân dụng thiết bị công nghiệp',
#    'sản xuất phụ tùng thay thế cho các thiết bị công nông ngư nghiệp',
#    'sản xuất các cấu kiện vật liệu xây dựng vật liệu trang trí nội thất',
#    'quản lý và kiểm định chất lượng nguyên vật liệu'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [220],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d365e': {'_id': '60588c802c992394968d365e',
#   'major_code': ['114'],
#   'major_name': ['kỹ thuật hóa học'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [853.0],
#   'year': ['2020'],
#   'career': ['quản lý vận hành và vận hành các hệ thống thiết bị công nghệ sản xuất ngành hóa',
#    'nghiên cứu và phát triển sản phẩm',
#    'phân tích và quản lý chất lượng sản phẩm'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [320],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d365f': {'_id': '60588c802c992394968d365f',
#   'major_code': ['117'],
#   'major_name': ['kiến trúc'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [762.0],
#   'year': ['2020'],
#   'career': ['thiết kế kiến trúc nội thất và đô thị',
#    'thiết kế môi trường',
#    'xây dựng quản lý và phát triển bất động sản'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [75],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3660': {'_id': '60588c802c992394968d3660',
#   'major_code': ['108'],
#   'major_name': ['kỹ thuật điện'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [68.4],
#   'year': ['2020'],
#   'career': ['thiết kế thiết bị điện và điện tử công suất',
#    'thiết kế bộ điều khiển máy điện',
#    'thiết kế hệ thống năng lượng tái tạo',
#    'thiết kế mạng điện',
#    'thiết kế trạm biến áp',
#    'thiết kế nhà máy điện',
#    'thiết kế và lập trình giải thuật điều khiển thiết bị và hệ thống điện',
#    'quản lý và vận hành lưới điện',
#    'thiết kế chiếu sáng',
#    'phân tích ổn định thiết bị và nguồn điện',
#    'bảo vệ relay và tự động hóa hệ thống điện',
#    'kỹ thuật cao áp',
#    'vật liệu cách điện',
#    'phân tích dữ liệu khoa học',
#    'phân tích hệ thống',
#    'điều khiển quá trình thời gian thực và lập trình giao tiếp người sử dụng'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [670],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3661': {'_id': '60588c802c992394968d3661',
#   'major_code': ['214'],
#   'major_name': ['kỹ thuật hóa học'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [79.3],
#   'year': ['2020'],
#   'career': ['quản lý vận hành và vận hành các hệ thống thiết bị công nghệ sản xuất ngành hóa',
#    'nghiên cứu và phát triển sản phẩm',
#    'phân tích và quản lý chất lượng sản phẩm'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [200],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3662': {'_id': '60588c802c992394968d3662',
#   'major_code': ['145'],
#   'major_name': ['kỹ thuật tàu thủy'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [26.5],
#   'year': ['2020'],
#   'career': ['quản lý điều hành thiết kế tư vấn trong lĩnh vực tàu thủy',
#    'chuyển giao công nghệ liên quan đến tàu thủy'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [60],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3663': {'_id': '60588c802c992394968d3663',
#   'major_code': ['242'],
#   'major_name': ['công nghệ kỹ thuật ô tô'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [71.9],
#   'year': ['2020'],
#   'career': ['tư vấn và chuyển giao công nghệ lĩnh vực ô tô và giao thông vận tải đường bộ',
#    'công nghiệp sản xuất và lắp ráp ô tô'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [50],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3664': {'_id': '60588c802c992394968d3664',
#   'major_code': ['209'],
#   'major_name': ['kỹ thuật cơ khí'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [711.0],
#   'year': ['2020'],
#   'career': ['chế tạo',
#    'điều hành',
#    'sản xuất',
#    'nghiên cứu phát triển',
#    'thiết kế sản phẩm cơ khí',
#    'tư vấn thiết kế',
#    'hệ thống nâng vận chuyển trong hệ thống dây chuyền tự động',
#    'sản xuất vật liệu xây dựng',
#    'sản xuất vật liệu và cấu kiện xây dựng',
#    'máy thi công cơ giới và máy chuyên dụng'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [50],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3665': {'_id': '60588c802c992394968d3665',
#   'major_code': ['120'],
#   'major_name': ['kỹ thuật địa chất'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [704.0],
#   'year': ['2020'],
#   'career': ['thí nghiệm đất đá',
#    'tư vấn xây dựng',
#    'xử lý nền móng',
#    'khoan khảo sát địa chất',
#    'thiết kế vật liệu địa kỹ thuật',
#    'khai thác nước',
#    'gia cố nền đất',
#    'xử lý địa chất động lực công trình',
#    'quy hoạch và điều tra tài nguyên nước dưới đất',
#    'quản lý môi trường',
#    'đánh giá tác động môi trường',
#    'cải tạo môi trường địa chất',
#    'khai thác và bảo vệ tài nguyên dầu khí',
#    'khai thác thăm dò khoáng sản',
#    'điều hành mỏ trong các mỏ khai thác'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [130],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3666': {'_id': '60588c802c992394968d3666',
#   'major_code': ['208'],
#   'major_name': ['kỹ thuật điện'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [23.0],
#   'year': ['2020'],
#   'career': ['thiết kế thiết bị điện và điện tử công suất',
#    'thiết kế bộ điều khiển máy điện',
#    'thiết kế hệ thống năng lượng tái tạo',
#    'thiết kế mạng điện',
#    'thiết kế trạm biến áp',
#    'thiết kế nhà máy điện',
#    'thiết kế và lập trình giải thuật điều khiển thiết bị và hệ thống điện',
#    'quản lý và vận hành lưới điện',
#    'thiết kế chiếu sáng',
#    'phân tích ổn định thiết bị và nguồn điện',
#    'bảo vệ relay và tự động hóa hệ thống điện',
#    'kỹ thuật cao áp',
#    'vật liệu cách điện',
#    'phân tích dữ liệu khoa học',
#    'phân tích hệ thống',
#    'điều khiển quá trình thời gian thực và lập trình giao tiếp người sử dụng'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [150],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3667': {'_id': '60588c802c992394968d3667',
#   'major_code': ['108'],
#   'major_name': ['kỹ thuật điện tử viễn thông'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [68.4],
#   'year': ['2020'],
#   'career': ['vận hành quản lý khai thác và thiết kế các mạng điện thoại cố định và di động mạng truyền dẫn quang viba thông tin vệ tinh phát thanh truyền hình mạng thông tin dữ liệu',
#    'phân tích và thiết kế các thiết bị thu phát cao tần các vi mạch số và vi mạch tương tự',
#    'vận hành máy móc trong nhà máy chế tạo linh kiện bán dẫn',
#    'lập trình và thiết kế phần cứng xử lý tín hiệu âm thanh hình ảnh và tín hiệu đa phương tiện'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [670],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3668': {'_id': '60588c802c992394968d3668',
#   'major_code': ['114'],
#   'major_name': ['kỹ thuật hóa học'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [82.7],
#   'year': ['2020'],
#   'career': ['quản lý vận hành và vận hành các hệ thống thiết bị công nghệ sản xuất ngành hóa',
#    'nghiên cứu và phát triển sản phẩm',
#    'phân tích và quản lý chất lượng sản phẩm'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [320],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3669': {'_id': '60588c802c992394968d3669',
#   'major_code': ['115'],
#   'major_name': ['kỹ thuật trắc địa bản đồ'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [70.6],
#   'year': ['2020'],
#   'career': ['lập bản đồ địa hình địa chính',
#    'xây dựng và quản lý',
#    'bố trí các công trình nhà cao tầng cầu hầm',
#    'xây dựng hệ thông tin địa lý và quản lý đất đai'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [645],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d366a': {'_id': '60588c802c992394968d366a',
#   'major_code': ['140'],
#   'major_name': ['kỹ thuật nhiệt'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [73.0],
#   'year': ['2020'],
#   'career': ['quản lý vận hành bảo trì các nhà máy xí nghiệp sử dụng nhiệt năng',
#    'sản xuất kinh doanh các thiết bị nhiệt lạnh',
#    'nghiên cứu tiết kiệm năng lượng và năng lượng tái tạo'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [80],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d366b': {'_id': '60588c802c992394968d366b',
#   'major_code': ['140'],
#   'major_name': ['kỹ thuật nhiệt'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [25.25],
#   'year': ['2020'],
#   'career': ['quản lý vận hành bảo trì các nhà máy xí nghiệp sử dụng nhiệt năng',
#    'sản xuất kinh doanh các thiết bị nhiệt lạnh',
#    'nghiên cứu tiết kiệm năng lượng và năng lượng tái tạo'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [80],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d366c': {'_id': '60588c802c992394968d366c',
#   'major_code': ['245'],
#   'major_name': ['kỹ thuật hàng không'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [77.3],
#   'year': ['2020'],
#   'career': ['quản lý điều hành hoạt động bảo dưỡng máy bay',
#    'nghiên cứu thiết kế các thiết bị bay',
#    'tư vấn thiết kế cơ khí các hệ thống năng lượng và quy trình sản xuất'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [40],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d366d': {'_id': '60588c802c992394968d366d',
#   'major_code': ['115'],
#   'major_name': ['kỹ thuật xây dựng cơ sở hạ tầng'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [700.0],
#   'year': ['2020'],
#   'career': ['thiết kế thi công và quản lý các công trình chuyên ngành xây dựng cấp thoát nước cho khu quy hoạch',
#    'tư vấn thiết kế thi công hệ thống cấp thoát nước',
#    'hạ tầng kỹ thuật công trình dân dụng công nghiệp các khu đô thị mới'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [645],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d366e': {'_id': '60588c802c992394968d366e',
#   'major_code': ['141'],
#   'major_name': ['bảo dưỡng công nghiệp'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [21.25],
#   'year': ['2020'],
#   'career': ['tổ chức quản lý bảo dưỡng',
#    'tổ chức quản lý kho',
#    'sửa chữa máy móc',
#    'duy trì sản xuất liên tục và cung cấp dịch vụ bảo trì hậu mãi'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [165],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d366f': {'_id': '60588c802c992394968d366f',
#   'major_code': ['129'],
#   'major_name': ['kỹ thuật vật liệu'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [700.0],
#   'year': ['2020'],
#   'career': ['sản xuất gia công vật liệu',
#    'chế tạo vật tư và thiết bị dân dụng thiết bị công nghiệp',
#    'sản xuất phụ tùng thay thế cho các thiết bị công nông ngư nghiệp',
#    'sản xuất các cấu kiện vật liệu xây dựng vật liệu trang trí nội thất',
#    'quản lý và kiểm định chất lượng nguyên vật liệu'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [220],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3670': {'_id': '60588c802c992394968d3670',
#   'major_code': ['128'],
#   'major_name': ['logistics và quản lý chuỗi cung ứng'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [82.0],
#   'year': ['2020'],
#   'career': ['quản lý và điều hành hệ thống sản xuất hay dịch vụ',
#    'quản lý vật tư và hoạch định tồn kho',
#    'các kỹ thuật tối ưu hóa nguồn lực sản xuất',
#    'kỹ thuật hỗ trợ ra quyết định',
#    'quản lý và kiểm soát chất lượng',
#    'logistics và chuỗi cung ứng',
#    'kỹ thuật điều độ nguồn lực',
#    'thiết kế hệ thống thông tin',
#    'thiết kế và áp dụng hệ thống sản xuất tinh gọn cho tổ chức'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3671': {'_id': '60588c802c992394968d3671',
#   'major_code': ['138'],
#   'major_name': ['cơ kỹ thuật'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [25.5],
#   'year': ['2020'],
#   'career': ['mô phỏng các bài toán thuộc lĩnh vực cơ học trong kỹ thuật',
#    'lập trình điều khiển máy bằng chương trình số',
#    'thiết kế hệ thống kỹ thuật nhà máy'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [50],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3672': {'_id': '60588c802c992394968d3672',
#   'major_code': ['123'],
#   'major_name': ['quản lý công nghiệp'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [26.5],
#   'year': ['2020'],
#   'career': ['quản lý nhà máy',
#    'hoạch định sản xuất',
#    'quản lý mua hàng và tồn kho',
#    'đánh giá trình độ công nghệ',
#    'quản lý con người',
#    'quản lý mua hàng',
#    'đánh giá các chương trình mua hàng',
#    'thiếp lập cấp độ vận hành và phối hợp các công tác trong vận hành',
#    'định hướng các điểm mấu chốt trong vận hành',
#    'quản lý chất lượng',
#    'phân tích chi tiết cơ sở dữ liệu và các bảng tính',
#    'kiểm định quá trình để xác định các khu vực cần cải tiến',
#    'quản lý việc thực hiện những thay đổi',
#    'lập kế hoạch và quản lý chuỗi cung ứng'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3673': {'_id': '60588c802c992394968d3673',
#   'major_code': ['145'],
#   'major_name': ['kỹ thuật hàng không'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [26.5],
#   'year': ['2020'],
#   'career': ['quản lý điều hành hoạt động bảo dưỡng máy bay',
#    'nghiên cứu thiết kế các thiết bị bay',
#    'tư vấn thiết kế cơ khí các hệ thống năng lượng và quy trình sản xuất'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [60],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3674': {'_id': '60588c802c992394968d3674',
#   'major_code': ['112'],
#   'major_name': ['kỹ thuật dệt'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [702.0],
#   'year': ['2020'],
#   'career': ['quản lý vận hành các dây chuyền sản xuất sợi dệt nhuộm',
#    'quản đốc xưởng sản xuất'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3675': {'_id': '60588c802c992394968d3675',
#   'major_code': ['137'],
#   'major_name': ['vật lý kỹ thuật'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [25.5],
#   'year': ['2020'],
#   'career': ['kỹ sư lâm sàng',
#    'chuyên gia thiết bị y tế',
#    'kinh doanh và sản xuất thiết bị y tế thiết bị trong lĩnh vực công nghệ sinh học công nghệ môi trường'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [50],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3676': {'_id': '60588c802c992394968d3676',
#   'major_code': ['223'],
#   'major_name': ['quản lý công nghiệp'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [67.6],
#   'year': ['2020'],
#   'career': ['quản lý nhà máy',
#    'hoạch định sản xuất',
#    'quản lý mua hàng và tồn kho',
#    'đánh giá trình độ công nghệ',
#    'quản lý con người',
#    'quản lý mua hàng',
#    'đánh giá các chương trình mua hàng',
#    'thiếp lập cấp độ vận hành và phối hợp các công tác trong vận hành',
#    'định hướng các điểm mấu chốt trong vận hành',
#    'quản lý chất lượng',
#    'phân tích chi tiết cơ sở dữ liệu và các bảng tính',
#    'kiểm định quá trình để xác định các khu vực cần cải tiến',
#    'quản lý việc thực hiện những thay đổi',
#    'lập kế hoạch và quản lý chuỗi cung ứng'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3677': {'_id': '60588c802c992394968d3677',
#   'major_code': ['210'],
#   'major_name': ['kỹ thuật cơ điện tử'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [26.25],
#   'year': ['2020'],
#   'career': ['quản lý điều hành giải pháp tự động hóa sử dụng hệ thống và sản phẩm cơ điện tử'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [50],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3678': {'_id': '60588c802c992394968d3678',
#   'major_code': ['138'],
#   'major_name': ['cơ kỹ thuật'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [703.0],
#   'year': ['2020'],
# ...
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3707': {'_id': '60588c802c992394968d3707',
#   'major_code': ['225'],
#   'major_name': ['quản lý tài nguyên môi trường'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [21.0],
#   'year': ['2020'],
#   'career': ['quản lý dự án các doanh nghiệp sản xuất các khu công nghiệp',
#    'tư vấn môi trường',
#    'quản lý tài nguyên môi trường',
#    'ban quản lý cải thiện vệ sinh môi trường các lưu vực thoát nước',
#    'cải tạo chất lượng nước trong lưu vực sông',
#    'quản lý chất thải rắn',
#    'lập báo cáo đánh giá tác động môi trường'],
#   'subject': ['toán', 'hóa học', 'sinh học'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['b00', 'b'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [60],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3708': {'_id': '60588c802c992394968d3708',
#   'major_code': ['125'],
#   'major_name': ['quản lý tài nguyên môi trường'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [24.25],
#   'year': ['2020'],
#   'career': ['quản lý dự án các doanh nghiệp sản xuất các khu công nghiệp',
#    'tư vấn môi trường',
#    'quản lý tài nguyên môi trường',
#    'ban quản lý cải thiện vệ sinh môi trường các lưu vực thoát nước',
#    'cải tạo chất lượng nước trong lưu vực sông',
#    'quản lý chất thải rắn',
#    'lập báo cáo đánh giá tác động môi trường'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3709': {'_id': '60588c802c992394968d3709',
#   'major_code': ['125'],
#   'major_name': ['kỹ thuật môi trường'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [24.25],
#   'year': ['2020'],
#   'career': ['tư vấn thiết kế và thi công xây dựng công trình',
#    'cơ sở hạ tầng kỹ thuật liên quan đến vệ sinh môi trường'],
#   'subject': ['toán', 'hóa học', 'sinh học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['b00', 'b'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d370a': {'_id': '60588c802c992394968d370a',
#   'major_code': ['228'],
#   'major_name': ['logistics và quản lý chuỗi cung ứng'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [26.0],
#   'year': ['2020'],
#   'career': ['quản lý và điều hành hệ thống sản xuất hay dịch vụ',
#    'quản lý vật tư và hoạch định tồn kho',
#    'các kỹ thuật tối ưu hóa nguồn lực sản xuất',
#    'kỹ thuật hỗ trợ ra quyết định',
#    'quản lý và kiểm soát chất lượng',
#    'logistics và chuỗi cung ứng',
#    'kỹ thuật điều độ nguồn lực',
#    'thiết kế hệ thống thông tin',
#    'thiết kế và áp dụng hệ thống sản xuất tinh gọn cho tổ chức'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [40],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d370b': {'_id': '60588c802c992394968d370b',
#   'major_code': ['114'],
#   'major_name': ['công nghệ thực phẩm'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [26.75],
#   'year': ['2020'],
#   'career': ['vận hành sản xuất thực phẩm',
#    'kiểm tra chất lượng sản phẩm thực phẩm',
#    'đảm bảo chất lượng sản phẩm thực phẩm',
#    'phân tích chất lượng và an toàn thực phẩm',
#    'thiết kế sản phẩm thực phẩm',
#    'quản lý an toàn thực phẩm',
#    'phụ trách dinh dưỡng thực phẩm'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [320],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d370c': {'_id': '60588c802c992394968d370c',
#   'major_code': ['108'],
#   'major_name': ['kỹ thuật điều khiển và tự động hóa'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [736.0],
#   'year': ['2020'],
#   'career': ['thiết kế và xây dựng hệ thống đo lường',
#    'điều khiển tự động',
#    'giám sát các hệ thống trong dầu khí',
#    'chế biến thức ăn nước uống',
#    'sản xuất',
#    'máy móc',
#    'dược',
#    'phân phối và quản lý năng lượng'],
#   'subject': [],
#   'tuition': ['5.850.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [670],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d370d': {'_id': '60588c802c992394968d370d',
#   'major_code': ['108'],
#   'major_name': ['kỹ thuật điện'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [26.75],
#   'year': ['2020'],
#   'career': ['thiết kế thiết bị điện và điện tử công suất',
#    'thiết kế bộ điều khiển máy điện',
#    'thiết kế hệ thống năng lượng tái tạo',
#    'thiết kế mạng điện',
#    'thiết kế trạm biến áp',
#    'thiết kế nhà máy điện',
#    'thiết kế và lập trình giải thuật điều khiển thiết bị và hệ thống điện',
#    'quản lý và vận hành lưới điện',
#    'thiết kế chiếu sáng',
#    'phân tích ổn định thiết bị và nguồn điện',
#    'bảo vệ relay và tự động hóa hệ thống điện',
#    'kỹ thuật cao áp',
#    'vật liệu cách điện',
#    'phân tích dữ liệu khoa học',
#    'phân tích hệ thống',
#    'điều khiển quá trình thời gian thực và lập trình giao tiếp người sử dụng'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [670],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d370e': {'_id': '60588c802c992394968d370e',
#   'major_code': ['129'],
#   'major_name': ['kỹ thuật vật liệu'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [23.0],
#   'year': ['2020'],
#   'career': ['sản xuất gia công vật liệu',
#    'chế tạo vật tư và thiết bị dân dụng thiết bị công nghiệp',
#    'sản xuất phụ tùng thay thế cho các thiết bị công nông ngư nghiệp',
#    'sản xuất các cấu kiện vật liệu xây dựng vật liệu trang trí nội thất',
#    'quản lý và kiểm định chất lượng nguyên vật liệu'],
#   'subject': ['toán', 'hóa học', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['d07', 'd7'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [220],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d370f': {'_id': '60588c802c992394968d370f',
#   'major_code': ['128'],
#   'major_name': ['logistics và quản lý chuỗi cung ứng'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [27.25],
#   'year': ['2020'],
#   'career': ['quản lý và điều hành hệ thống sản xuất hay dịch vụ',
#    'quản lý vật tư và hoạch định tồn kho',
#    'các kỹ thuật tối ưu hóa nguồn lực sản xuất',
#    'kỹ thuật hỗ trợ ra quyết định',
#    'quản lý và kiểm soát chất lượng',
#    'logistics và chuỗi cung ứng',
#    'kỹ thuật điều độ nguồn lực',
#    'thiết kế hệ thống thông tin',
#    'thiết kế và áp dụng hệ thống sản xuất tinh gọn cho tổ chức'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3710': {'_id': '60588c802c992394968d3710',
#   'major_code': ['242'],
#   'major_name': ['công nghệ kỹ thuật ô tô'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [25.75],
#   'year': ['2020'],
#   'career': ['tư vấn và chuyển giao công nghệ lĩnh vực ô tô và giao thông vận tải đường bộ',
#    'công nghiệp sản xuất và lắp ráp ô tô'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [50],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3711': {'_id': '60588c802c992394968d3711',
#   'major_code': ['107'],
#   'major_name': ['kỹ thuật máy tính'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [27.25],
#   'year': ['2020'],
#   'career': ['thiết kế và xây dựng các phầm mềm phần cứng cho các thiết bị điều khiển tự động',
#    'quản trị và xây dựng các giải pháp đảm bảo an toàn cho các hệ thống máy tính và mạng máy tính',
#    'tư vấn thẩm định và phát triển các dự án giải pháp công nghệ thông tin'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [100],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3712': {'_id': '60588c802c992394968d3712',
#   'major_code': ['215'],
#   'major_name': ['kỹ thuật công trình xây dựng'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [21.0],
#   'year': ['2020'],
#   'career': ['thiết kế',
#    'thi công',
#    'quản lý thi công',
#    'thẩm tra thiết kế',
#    'quản lý dự án xây dựng',
#    'khảo sát và kiểm định công trình'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [80],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3713': {'_id': '60588c802c992394968d3713',
#   'major_code': ['115'],
#   'major_name': ['kỹ thuật công trình xây dựng'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [24.0],
#   'year': ['2020'],
#   'career': ['thiết kế',
#    'thi công',
#    'quản lý thi công',
#    'thẩm tra thiết kế',
#    'quản lý dự án xây dựng',
#    'khảo sát và kiểm định công trình'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [645],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3714': {'_id': '60588c802c992394968d3714',
#   'major_code': ['225'],
#   'major_name': ['quản lý tài nguyên môi trường'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [21.0],
#   'year': ['2020'],
#   'career': ['quản lý dự án các doanh nghiệp sản xuất các khu công nghiệp',
#    'tư vấn môi trường',
#    'quản lý tài nguyên môi trường',
#    'ban quản lý cải thiện vệ sinh môi trường các lưu vực thoát nước',
#    'cải tạo chất lượng nước trong lưu vực sông',
#    'quản lý chất thải rắn',
#    'lập báo cáo đánh giá tác động môi trường'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['30.000.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [60],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3715': {'_id': '60588c802c992394968d3715',
#   'major_code': ['117'],
#   'major_name': ['kiến trúc'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [24.5],
#   'year': ['2020'],
#   'career': ['thiết kế kiến trúc nội thất và đô thị',
#    'thiết kế môi trường',
#    'xây dựng quản lý và phát triển bất động sản'],
#   'subject': ['toán', 'ngữ văn', 'vẽ hình họa mỹ thuật'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['v01', 'v1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [75],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3716': {'_id': '60588c802c992394968d3716',
#   'major_code': ['228'],
#   'major_name': ['logistics và quản lý chuỗi cung ứng'],
#   'type_edu': ['chất lượng cao', 'tiên tiến'],
#   'point': [897.0],
#   'year': ['2020'],
#   'career': ['quản lý và điều hành hệ thống sản xuất hay dịch vụ',
#    'quản lý vật tư và hoạch định tồn kho',
#    'các kỹ thuật tối ưu hóa nguồn lực sản xuất',
#    'kỹ thuật hỗ trợ ra quyết định',
#    'quản lý và kiểm soát chất lượng',
#    'logistics và chuỗi cung ứng',
#    'kỹ thuật điều độ nguồn lực',
#    'thiết kế hệ thống thông tin',
#    'thiết kế và áp dụng hệ thống sản xuất tinh gọn cho tổ chức'],
#   'subject': [],
#   'tuition': ['30.000.000'],
#   'subject_group': [],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [40],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3717': {'_id': '60588c802c992394968d3717',
#   'major_code': ['138'],
#   'major_name': ['cơ kỹ thuật'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [25.5],
#   'year': ['2020'],
#   'career': ['mô phỏng các bài toán thuộc lĩnh vực cơ học trong kỹ thuật',
#    'lập trình điều khiển máy bằng chương trình số',
#    'thiết kế hệ thống kỹ thuật nhà máy'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [50],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3719': {'_id': '60588c802c992394968d3719',
#   'major_code': ['142'],
#   'major_name': ['công nghệ kỹ thuật ô tô'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [27.5],
#   'year': ['2020'],
#   'career': ['tư vấn và chuyển giao công nghệ lĩnh vực ô tô và giao thông vận tải đường bộ',
#    'công nghiệp sản xuất và lắp ráp ô tô'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [90],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d3720': {'_id': '60588c802c992394968d3720',
#   'major_code': ['125'],
#   'major_name': ['quản lý tài nguyên môi trường'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [24.25],
#   'year': ['2020'],
#   'career': ['quản lý dự án các doanh nghiệp sản xuất các khu công nghiệp',
#    'tư vấn môi trường',
#    'quản lý tài nguyên môi trường',
#    'ban quản lý cải thiện vệ sinh môi trường các lưu vực thoát nước',
#    'cải tạo chất lượng nước trong lưu vực sông',
#    'quản lý chất thải rắn',
#    'lập báo cáo đánh giá tác động môi trường'],
#   'subject': ['toán', 'vật lý', 'tiếng anh'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a01', 'a1'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [120],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  '60588c802c992394968d372f': {'_id': '60588c802c992394968d372f',
#   'major_code': ['140'],
#   'major_name': ['kỹ thuật nhiệt'],
#   'type_edu': ['chính quy', 'đại trà'],
#   'point': [25.25],
#   'year': ['2020'],
#   'career': ['quản lý vận hành bảo trì các nhà máy xí nghiệp sử dụng nhiệt năng',
#    'sản xuất kinh doanh các thiết bị nhiệt lạnh',
#    'nghiên cứu tiết kiệm năng lượng và năng lượng tái tạo'],
#   'subject': ['toán', 'vật lý', 'hóa học'],
#   'tuition': ['5.850.000'],
#   'subject_group': ['a00', 'a'],
#   'case': ['thi tốt nghiệp trung học phổ thông'],
#   'criteria': [80],
#   'object': ['thi tốt nghiệp thpt năm 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']}}

# %%
# dbquery = DBQuery(database)
# constraint = {'major_name': ['điện tử'],'point':[float(20),float(27)]}
# constraint = {}
# constraint = {'major_name': ['bảo dưỡng công nghiệp']}
constraint = {'major_name': ['bảo dưỡng công nghiệp'], 'type_edu': ['chính quy'], 'case': 'anything', 'subject_group': []}
user_action = {}
# user_action = {'inform_slots': {'type_edu': ['đại trà']}, 'intent': 'inform', 'request_slots': {}, 'round': 1, 'speaker': 'User'}
# user_action['intent'] = 'request'
dbquery.get_db_results_for_slots(constraint,user_action)
# Out:
# {'major_name': 11,
#  'type_edu': 220,
#  'case': 0,
#  'subject_group': 327,
#  'matching_all_constraints': 6}

# %%
for keys,values in constraint.items():
    for value in values:
        print(value)
# Out:
# bảo dưỡng công nghiệp
# chính quy
# a
# n
# y
# t
# h
# i
# n
# g

# %%
import pymongo
import re
import numpy as np

# data=mycol.find({
#   "$and": [
#     {
#     "$or":[
#   {"major_name": {"$all": [re.compile("máy tính")]}},
#   {"major_name": {"$all": [re.compile("kỹ thuật hóa")]}}
#     ]},
#   {"type_edu": {"$all": [re.compile("chất lượng cao")]}}
#   ]
# })
def convert_to_regex_constraint(key,values):
    or_list = []
    final_list = []
    or_dict = {}
#     print('key',key)
    if key != 'point':
        if len(values) > 1:
            for value in values:
                all_dict = {}
                all_dict[key] = {"$all":[re.compile(value)]}
                or_list.append(all_dict)
            or_dict["$or"] = or_list
            final_list.append(or_dict)
        elif len(values) == 1:
            all_dict = {}
            all_dict[key] = {"$all":[re.compile(values[0])]}
            final_list.append(all_dict)
        else:
            print('neeee')
            all_dict = {}
            all_dict[key] = {"$all":[re.compile('')]}
            final_list.append(all_dict)
    else:
        all_dict = {}
        all_dict["point"] = {"$gte":values[0],"$lte":values[1]}
        final_list.append(all_dict)
    return final_list[0]


def convert_constraint(constraints,user_action):
    """
    input dict các thực thể theo từng slot {entity_slot:[entity_mess]}
    return câu query mongodb
    form của câu query: { "$and": [{entity_slot:{"$all":[re.compile("entity_mess")]}},{},{}] }
    """
    if user_action["intent"] == "request":
        listkeys = list(constraints.keys())
    and_list = []
    and_dict = {}
    if listkeys:
        for key in listkeys:
            values = constraints[key]
            and_list.append(convert_to_regex_constraint(key,values))
        and_dict["$and"] = and_list
    return and_dict

if __name__ == '__main__':
    client = pymongo.MongoClient("mongodb://taindp:chatbot2020@thesis-shard-00-00.bdisf.mongodb.net:27017,thesis-shard-00-01.bdisf.mongodb.net:27017,thesis-shard-00-02.bdisf.mongodb.net:27017/hcmut?ssl=true&replicaSet=atlas-12fynb-shard-0&authSource=admin&retryWrites=true&w=majority")
    db = client.hcmut
    collection = db['general'].find({})

#     constr = {'major_name': ['hóa'], 'year': ['2019','2020']}
#     constraint = {'major_name': ['điện tử']}
    constraint = {}
    mycol = db['general']
    user_action = {}
    user_action['intent'] = 'request'
    
#     print(convert_constraint(constraint,user_action))
#     print(constraint.keys())
    data=mycol.find(convert_constraint(constraint,user_action))
    count = 0
    for x in data:
        count += 1
#         print(x['major_name'])
count
# Out:
# 327

# %%
# a = []
# len(a)

# %%
# agent_action = get_agent_action(state_tracker, dqn_agent, user_action,False)
# agent_action

# %%
# state_tracker.reset()
